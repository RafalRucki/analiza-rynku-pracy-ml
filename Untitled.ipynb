# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Test czy biblioteki się widzą
print("Środowisko gotowe! Pandas version:", pd.__version__)

url = "https://www.olx.pl/nieruchomosci/mieszkania/wynajem/warszawa/"
response = requests.get(url)
print("Status połączenia z OLX:", response.status_code)
# Jeśli 200 - jest OK!
# Out:
# /Users/rafalrucki/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Środowisko gotowe! Pandas version: 2.2.3
# Status połączenia z OLX: 200
